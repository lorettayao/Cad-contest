# %%
# !pip install networkx matplotlib
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (3.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import re
import numpy as np
import networkx as nx
import json
from scipy.sparse import lil_matrix, save_npz

# ===== Step 1: 解析 Verilog 檔案 =====
def parse_verilog(verilog_code):
    gates = []

    for line in verilog_code.splitlines():
        line = line.strip()
        print(f"Processing line: {line}")

        # 解析 BUF gate
        buf_match = re.match(r'^\s*buf\s+(\S+)\((\S+),\s*(\S+)\);', line)
        if buf_match:
            gates.append(('BUF', buf_match.group(1), buf_match.group(2), buf_match.group(3)))  # buf, output, input
            continue

        # 解析 DFF gate（具名端口的 DFF gate，處理 .RN, .SN 等）
        dff_match = re.match(r'^\s*dff\s+(\S+)\s*\(\.RN\(([^)]+)\),\s*\.SN\(([^)]+)\),\s*\.CK\(([^)]+)\),\s*\.D\(([^)]+)\),\s*\.Q\(([^)]+)\)\);', line)
        if dff_match:
            gates.append(('DFF', dff_match.group(1), dff_match.group(2), dff_match.group(3),
                          dff_match.group(4), dff_match.group(5), dff_match.group(6)))  # dff, RN, SN, CK, D, Q
            continue

        # 解析 OR gate (雙輸入 gate)
        or_match = re.match(r'^\s*or\s+(\S+)\((\S+)\s*,\s*(\S+)\s*,\s*(\S+)\);', line)
        if or_match:
            gates.append(('OR', or_match.group(1), or_match.group(2), or_match.group(3), or_match.group(4)))  # or, output, input1, input2
            continue

        # 解析 NOR gate (雙輸入 gate)
        nor_match = re.match(r'^\s*nor\s+(\S+)\((\S+)\s*,\s*(\S+)\s*,\s*(\S+)\);', line)
        if nor_match:
            gates.append(('NOR', nor_match.group(1), nor_match.group(2), nor_match.group(3), nor_match.group(4)))  # nor, output, input1, input2
            continue

        # 解析 NOT gate (單輸入 gate)
        not_match = re.match(r'^\s*not\s+(\S+)\((\S+)\s*,\s*(\S+)\);', line)
        if not_match:
            gates.append(('NOT', not_match.group(1), not_match.group(2), not_match.group(3)))  # not, output, input
            continue

        # 解析 XOR gate (雙輸入 gate)
        xor_match = re.match(r'^\s*xor\s+(\S+)\((\S+)\s*,\s*(\S+)\s*,\s*(\S+)\);', line)
        if xor_match:
            gates.append(('XOR', xor_match.group(1), xor_match.group(2), xor_match.group(3), xor_match.group(4)))  # xor, output, input1, input2
            continue

        # 解析 AND gate (雙輸入 gate)
        and_match = re.match(r'^\s*and\s+(\S+)\((\S+)\s*,\s*(\S+)\s*,\s*(\S+)\);', line)
        if and_match:
            gates.append(('AND', and_match.group(1), and_match.group(2), and_match.group(3), and_match.group(4)))  # and, output, input1, input2
            continue

        # 解析 NAND gate (雙輸入 gate)
        nand_match = re.match(r'^\s*nand\s+(\S+)\((\S+)\s*,\s*(\S+)\s*,\s*(\S+)\);', line)
        if nand_match:
            gates.append(('NAND', nand_match.group(1), nand_match.group(2), nand_match.group(3), nand_match.group(4)))  # nand, output, input1, input2
            continue

    #print(gates)
    return gates


# ===== Step 2: 轉換成 infolist 格式 =====
def gates_to_infolist(gates, trojan_gates=[]):
    infolist = []
    for g in gates:
        gtype = g[0]
        instname = g[1]
        output = g[2]
        inputs = list(g[3:])

        portnames = ['Y'] + [f'A{i+1}' for i in range(len(inputs))]
        connnames = [output] + inputs

        is_trojan = (instname in trojan_gates or output in trojan_gates or any(inp in trojan_gates for inp in inputs))
        infolist.append((
            gtype, gtype, instname, instname, portnames, connnames, is_trojan
        ))
    return infolist

# ===== Step 3: 建立 adjacency matrix & features =====
def build_lookup(infolist):
    lookup = {}
    for i, info in enumerate(infolist):
        conns = info[5]  # connection names
        for conn in conns[1:]:  # skip output
            if conn not in lookup:
                lookup[conn] = []
            lookup[conn].append(i)
    return lookup

def build_graph_features(infolist):
    numnodes = len(infolist)
    adj = lil_matrix((numnodes, numnodes), dtype=bool)
    class_map = {}
    train_indices = list(range(numnodes))  # 全部都當 train

    gatelist = sorted(list(set([x[0] for x in infolist])))
    gatelookup = {g: i for i, g in enumerate(gatelist)}

    feats = np.zeros((numnodes, len(gatelist) + 2))
    lookup = build_lookup(infolist)

    gate_map = {}  # <== 新增這行

    for i, info in enumerate(infolist):
        gatetype = info[0]
        conns = info[5]
        feats[i][gatelookup[gatetype]] = 1

        for conn in conns[1:]:  # skip output
            if conn in lookup:
                for j in lookup[conn]:
                    if i != j:
                        adj[i, j] = True
                        feats[i][-1] += 1  # out
                        feats[j][-2] += 1  # in

        class_map[i] = 1 if info[6] else 0
        gate_map[i] = info[2]  # <== index i 對應 gate 名稱

    return adj, feats, train_indices, class_map, gate_map


# ===== Step 4: 儲存 GraphSAGE 所需格式 =====
def save_graphsage_format(adj, feats, class_map, train_indices, gate_map):
    save_npz("adj_full.npz", adj.tocsr())
    save_npz("adj_train.npz", adj.tocsr())

    np.save("feats.npy", feats, allow_pickle=False)

    with open("class_map.json", "w") as f:
        json.dump(class_map, f)

    with open("role.json", "w") as f:
        json.dump({'tr': train_indices, 'va': [], 'te': []}, f)

    with open("gate_map.json", "w") as f:  # <== 新增這段
        json.dump(gate_map, f)


# ===== 主流程 =====
def process_single_verilog(filepath, gt_trojan_filepath):
    with open(filepath, 'r') as f:
        code = f.read()

    gates = parse_verilog(code)
    # 若無trojan gates, txt只有一行: NO_TROJAN
    # 若有trojan gates, txt第一行是 "TROJANED", 第二行是 "TROJAN_GATES", 最後一行是 "END_TROJAN_GATES"
    trojan_gates = []
    with open(gt_trojan_filepath, 'r') as f:
        lines = [l.strip() for l in f]
        if lines and lines[0] == "TROJANED":
            for line in lines[2:]:
                if line == "END_TROJAN_GATES":
                    break
                trojan_gates.append(line)
        else:
            trojan_gates = []
    infolist = gates_to_infolist(gates, trojan_gates)
    adj, feats, train_indices, class_map, gate_map = build_graph_features(infolist)
    save_graphsage_format(adj, feats, class_map, train_indices, gate_map)


    print("✅ Graph feature files saved.")

if __name__ == "__main__":
    process_single_verilog("design4.v", "result4.txt")  # 改成你的檔案
# Out:
# Processing line: module top(n0, n1, n2, n3, n4, n5);
# Processing line: input n0, n1;
# Processing line: input [127:0] n2;
# Processing line: output [63:0] n3, n4, n5;
# Processing line: wire n0, n1;
# Processing line: wire [127:0] n2;
# Processing line: wire [63:0] n3, n4, n5;
# Processing line: wire [63:0] n6;
# Processing line: wire [63:0] n7;
# Processing line: wire [63:0] n8;
# Processing line: wire [63:0] n9;
# Processing line: wire [63:0] n10;
# Processing line: wire [63:0] n11;
# Processing line: wire [2:0] n12;
# Processing line: wire [3:0] n13;
# Processing line: wire [15:0] n14;
# Processing line: wire n15, n16, n17, n18, n19, n20, n21, n22;
# Processing line: wire n23, n24, n25, n26, n27, n28, n29, n30;
# Processing line: wire n31, n32, n33, n34, n35, n36, n37, n38;
# Processing line: wire n39, n40, n41, n42, n43, n44, n45, n46;
# Processing line: wire n47, n48, n49, n50, n51, n52, n53, n54;
# Processing line: wire n55, n56, n57, n58, n59, n60, n61, n62;
# Processing line: wire n63, n64, n65, n66, n67, n68, n69, n70;
# Processing line: wire n71, n72, n73, n74, n75, n76, n77, n78;
# Processing line: wire n79, n80, n81, n82, n83, n84, n85, n86;
# Processing line: wire n87, n88, n89, n90, n91, n92, n93, n94;
# Processing line: wire n95, n96, n97, n98, n99, n100, n101, n102;
# Processing line: wire n103, n104, n105, n106, n107, n108, n109, n110;
# Processing line: wire n111, n112, n113, n114, n115, n116, n117, n118;
# Processing line: wire n119, n120, n121, n122, n123, n124, n125, n126;
# Processing line: wire n127, n128, n129, n130, n131, n132, n133, n134;
# Processing line: wire n135, n136, n137, n138, n139, n140, n141, n142;
# Processing line: wire n143, n144, n145, n146, n147, n148, n149, n150;
# Processing line: wire n151, n152, n153, n154, n155, n156, n157, n158;
# Processing line: wire n159, n160, n161, n162, n163, n164, n165, n166;
# Processing line: wire n167, n168, n169, n170, n171, n172, n173, n174;
# Processing line: wire n175, n176, n177, n178, n179, n180, n181, n182;
# Processing line: wire n183, n184, n185, n186, n187, n188, n189, n190;
# Processing line: wire n191, n192, n193, n194, n195, n196, n197, n198;
# Processing line: wire n199, n200, n201, n202, n203, n204, n205, n206;
# Processing line: wire n207, n208, n209, n210, n211, n212, n213, n214;
# Processing line: wire n215, n216, n217, n218, n219, n220, n221, n222;
# Processing line: wire n223, n224, n225, n226, n227, n228, n229, n230;
# Processing line: wire n231, n232, n233, n234, n235, n236, n237, n238;
# Processing line: wire n239, n240, n241, n242, n243, n244, n245, n246;
# Processing line: wire n247, n248, n249, n250, n251, n252, n253, n254;
# Processing line: wire n255, n256, n257, n258, n259, n260, n261, n262;
# Processing line: wire n263, n264, n265, n266, n267, n268, n269, n270;
# Processing line: wire n271, n272, n273, n274, n275, n276, n277, n278;
# Processing line: wire n279, n280, n281, n282, n283, n284, n285, n286;
# Processing line: wire n287, n288, n289, n290, n291, n292, n293, n294;
# Processing line: wire n295, n296, n297, n298, n299, n300, n301, n302;
# Processing line: wire n303, n304, n305, n306, n307, n308, n309, n310;
# Processing line: wire n311, n312, n313, n314, n315, n316, n317, n318;
# Processing line: wire n319, n320, n321, n322, n323, n324, n325, n326;
# Processing line: wire n327, n328, n329, n330, n331, n332, n333, n334;
# Processing line: wire n335, n336, n337, n338, n339, n340, n341, n342;
# Processing line: wire n343, n344, n345, n346, n347, n348, n349, n350;
# Processing line: wire n351, n352, n353, n354, n355, n356, n357, n358;
# Processing line: wire n359, n360, n361, n362, n363, n364, n365, n366;
# Processing line: wire n367, n368, n369, n370, n371, n372, n373, n374;
# Processing line: wire n375, n376, n377, n378, n379, n380, n381, n382;
# Processing line: wire n383, n384, n385, n386, n387, n388, n389, n390;
# Processing line: wire n391, n392, n393, n394, n395, n396, n397, n398;
# Processing line: wire n399, n400, n401, n402, n403, n404, n405, n406;
# Processing line: wire n407, n408, n409, n410, n411, n412, n413, n414;
# Processing line: wire n415, n416, n417, n418, n419, n420, n421, n422;
# Processing line: wire n423, n424, n425, n426, n427, n428, n429, n430;
# Processing line: wire n431, n432, n433, n434, n435, n436, n437, n438;
# Processing line: wire n439, n440, n441, n442, n443, n444, n445, n446;
# Processing line: wire n447, n448, n449, n450, n451, n452, n453, n454;
# Processing line: wire n455, n456, n457, n458, n459, n460, n461, n462;
# Processing line: wire n463, n464, n465, n466, n467, n468, n469, n470;
# Processing line: wire n471, n472, n473, n474, n475, n476, n477, n478;
# Processing line: wire n479, n480, n481, n482, n483, n484, n485, n486;
# Processing line: wire n487, n488, n489, n490, n491, n492, n493, n494;
# Processing line: wire n495, n496, n497, n498, n499, n500, n501, n502;
# Processing line: wire n503, n504, n505, n506, n507, n508, n509, n510;
# Processing line: wire n511, n512, n513, n514, n515, n516, n517, n518;
# Processing line: wire n519, n520, n521, n522, n523, n524, n525, n526;
# Processing line: wire n527, n528, n529, n530, n531, n532, n533, n534;
# Processing line: wire n535, n536, n537, n538, n539, n540, n541, n542;
# Processing line: wire n543, n544, n545, n546, n547, n548, n549, n550;
# Processing line: wire n551, n552, n553, n554, n555, n556, n557, n558;
# Processing line: wire n559, n560, n561, n562, n563, n564, n565, n566;
# Processing line: wire n567, n568, n569, n570, n571, n572, n573, n574;
# Processing line: wire n575, n576, n577, n578, n579, n580, n581, n582;
# Processing line: wire n583, n584, n585, n586, n587, n588, n589, n590;
# Processing line: wire n591, n592, n593, n594, n595, n596, n597, n598;
# Processing line: wire n599, n600, n601, n602, n603, n604, n605, n606;
# Processing line: wire n607, n608, n609, n610, n611, n612, n613, n614;
# Processing line: wire n615, n616, n617, n618, n619, n620, n621, n622;
# Processing line: wire n623, n624, n625, n626, n627, n628, n629, n630;
# Processing line: wire n631, n632, n633, n634, n635, n636, n637, n638;
# Processing line: wire n639, n640, n641, n642, n643, n644, n645, n646;
# Processing line: wire n647, n648, n649, n650, n651, n652, n653, n654;
# Processing line: wire n655, n656, n657, n658, n659, n660, n661, n662;
# Processing line: wire n663, n664, n665, n666, n667, n668, n669, n670;
# Processing line: wire n671, n672, n673, n674, n675, n676, n677, n678;
# Processing line: wire n679, n680, n681, n682, n683, n684, n685, n686;
# Processing line: wire n687, n688, n689, n690, n691, n692, n693, n694;
# Processing line: wire n695, n696, n697, n698, n699, n700, n701, n702;
# Processing line: wire n703, n704, n705, n706, n707, n708, n709, n710;
# Processing line: wire n711, n712, n713, n714, n715, n716, n717, n718;
# Processing line: wire n719, n720, n721, n722, n723, n724, n725, n726;
# Processing line: wire n727, n728, n729, n730, n731, n732, n733, n734;
# Processing line: wire n735, n736, n737, n738, n739, n740, n741, n742;
# Processing line: wire n743, n744, n745, n746, n747, n748, n749, n750;
# Processing line: wire n751, n752, n753, n754, n755, n756, n757, n758;
# Processing line: wire n759, n760, n761, n762, n763, n764, n765, n766;
# Processing line: wire n767, n768, n769, n770, n771, n772, n773, n774;
# Processing line: wire n775, n776, n777, n778, n779, n780, n781, n782;
# Processing line: wire n783, n784, n785, n786, n787, n788, n789, n790;
# Processing line: wire n791, n792, n793, n794, n795, n796, n797, n798;
# Processing line: wire n799, n800, n801, n802, n803, n804, n805, n806;
# Processing line: wire n807, n808, n809, n810, n811, n812, n813, n814;
# Processing line: wire n815, n816, n817, n818, n819, n820, n821, n822;
# Processing line: wire n823, n824, n825, n826, n827, n828, n829, n830;
# Processing line: wire n831, n832, n833, n834, n835, n836, n837, n838;
# Processing line: wire n839, n840, n841, n842, n843, n844, n845, n846;
# Processing line: wire n847, n848, n849, n850, n851, n852, n853, n854;
# Processing line: wire n855, n856, n857, n858, n859, n860, n861, n862;
# Processing line: wire n863, n864, n865, n866, n867, n868, n869, n870;
# Processing line: wire n871, n872, n873, n874, n875, n876, n877, n878;
# Processing line: wire n879, n880, n881, n882, n883, n884, n885, n886;
# Processing line: wire n887, n888, n889, n890, n891, n892, n893, n894;
# Processing line: wire n895, n896, n897, n898, n899, n900, n901, n902;
# Processing line: wire n903, n904, n905, n906, n907, n908, n909, n910;
# Processing line: wire n911, n912, n913, n914, n915, n916, n917, n918;
# Processing line: wire n919, n920, n921, n922, n923, n924, n925, n926;
# Processing line: wire n927, n928, n929, n930, n931, n932, n933, n934;
# Processing line: wire n935, n936, n937, n938, n939, n940, n941, n942;
# Processing line: wire n943, n944, n945, n946, n947, n948, n949, n950;
# Processing line: wire n951, n952, n953, n954, n955, n956, n957, n958;
# Processing line: wire n959, n960, n961, n962, n963, n964, n965, n966;
# Processing line: wire n967, n968, n969, n970, n971, n972, n973, n974;
# Processing line: wire n975, n976, n977, n978, n979, n980, n981, n982;
# Processing line: wire n983, n984, n985, n986, n987, n988, n989, n990;
# Processing line: wire n991, n992, n993, n994, n995, n996, n997, n998;
# Processing line: wire n999, n1000, n1001, n1002, n1003, n1004, n1005, n1006;
# Processing line: wire n1007, n1008, n1009, n1010, n1011, n1012, n1013, n1014;
# Processing line: wire n1015, n1016, n1017, n1018, n1019, n1020, n1021, n1022;
# Processing line: wire n1023, n1024, n1025, n1026, n1027, n1028, n1029, n1030;
# Processing line: wire n1031, n1032, n1033, n1034, n1035, n1036, n1037, n1038;
# Processing line: wire n1039, n1040, n1041, n1042, n1043, n1044, n1045, n1046;
# Processing line: wire n1047, n1048, n1049, n1050, n1051, n1052, n1053, n1054;
# Processing line: wire n1055, n1056, n1057, n1058, n1059, n1060, n1061, n1062;
# Processing line: wire n1063, n1064, n1065, n1066, n1067, n1068, n1069, n1070;
# Processing line: wire n1071, n1072, n1073, n1074, n1075, n1076, n1077, n1078;
# Processing line: wire n1079, n1080, n1081, n1082, n1083, n1084, n1085, n1086;
# Processing line: wire n1087, n1088, n1089, n1090, n1091, n1092, n1093, n1094;
# Processing line: wire n1095, n1096, n1097, n1098, n1099, n1100, n1101, n1102;
# Processing line: wire n2927, n2928, n2929, n2930, n2931, n2932, n2933, n2934;
# Processing line: wire n2935, n2936, n2937, n2938, n2939, n2940;
# Processing line: not g0(n2488 ,n6[13]);
# Processing line: not g1(n2487 ,n6[11]);
# Processing line: not g2(n2486 ,n6[7]);
# Processing line: not g3(n2485 ,n6[12]);
# Processing line: not g4(n2484 ,n6[6]);
# Processing line: not g5(n2483 ,n6[10]);
# Processing line: not g6(n2482 ,n6[5]);
# Processing line: not g7(n2481 ,n6[4]);
# Processing line: not g8(n2480 ,n6[9]);
# Processing line: not g9(n2479 ,n6[3]);
# Processing line: not g10(n2478 ,n6[14]);
# Processing line: not g11(n2477 ,n6[1]);
# Processing line: not g12(n2476 ,n6[8]);
# Processing line: not g13(n2475 ,n6[2]);
# Processing line: xnor g14(n5[45] ,n2462 ,n7[45]);
# Processing line: xnor g15(n3[47] ,n2474 ,n8[47]);
# Processing line: xnor g16(n3[16] ,n2466 ,n8[16]);
# Processing line: xnor g17(n4[16] ,n2466 ,n9[16]);
# Processing line: xnor g18(n4[15] ,n2474 ,n9[15]);
# Processing line: xnor g19(n3[15] ,n2474 ,n8[15]);
# Processing line: xnor g20(n5[48] ,n2466 ,n7[48]);
# Processing line: xnor g21(n5[47] ,n2474 ,n7[47]);
# Processing line: xnor g22(n5[32] ,n2466 ,n7[32]);
# Processing line: xnor g23(n5[31] ,n2474 ,n7[31]);
# Processing line: xnor g24(n3[32] ,n2466 ,n8[32]);
# Processing line: xnor g25(n4[48] ,n2466 ,n9[48]);
# Processing line: xnor g26(n5[16] ,n2466 ,n7[16]);
# Processing line: xnor g27(n5[15] ,n2474 ,n7[15]);
# Processing line: xnor g28(n4[47] ,n2474 ,n9[47]);
# Processing line: xnor g29(n3[31] ,n2474 ,n8[31]);
# Processing line: xnor g30(n4[32] ,n2466 ,n9[32]);
# Processing line: xnor g31(n4[31] ,n2474 ,n9[31]);
# Processing line: xnor g32(n3[51] ,n2471 ,n8[51]);
# Processing line: xnor g33(n3[28] ,n2468 ,n8[28]);
# Processing line: xnor g34(n4[29] ,n2462 ,n9[29]);
# Processing line: xnor g35(n4[28] ,n2468 ,n9[28]);
# Processing line: xnor g36(n3[27] ,n2464 ,n8[27]);
# Processing line: xnor g37(n4[27] ,n2464 ,n9[27]);
# Processing line: xnor g38(n4[26] ,n2460 ,n9[26]);
# Processing line: xnor g39(n3[26] ,n2460 ,n8[26]);
# Processing line: xnor g40(n4[25] ,n2470 ,n9[25]);
# Processing line: xnor g41(n4[24] ,n2467 ,n9[24]);
# Processing line: xnor g42(n3[25] ,n2470 ,n8[25]);
# Processing line: xnor g43(n4[23] ,n2465 ,n9[23]);
# Processing line: xnor g44(n4[22] ,n2463 ,n9[22]);
# Processing line: xnor g45(n3[23] ,n2465 ,n8[23]);
# Processing line: xnor g46(n4[21] ,n2461 ,n9[21]);
# Processing line: xnor g47(n4[20] ,n2459 ,n9[20]);
# Processing line: xnor g48(n4[19] ,n2471 ,n9[19]);
# Processing line: xnor g49(n4[18] ,n2469 ,n9[18]);
# Processing line: xnor g50(n3[57] ,n2470 ,n8[57]);
# Processing line: xnor g51(n3[22] ,n2463 ,n8[22]);
# Processing line: xnor g52(n4[17] ,n2473 ,n9[17]);
# Processing line: xnor g53(n3[24] ,n2467 ,n8[24]);
# Processing line: xnor g54(n3[21] ,n2461 ,n8[21]);
# Processing line: xnor g55(n4[14] ,n2472 ,n9[14]);
# Processing line: xnor g56(n3[50] ,n2469 ,n8[50]);
# Processing line: xnor g57(n3[20] ,n2459 ,n8[20]);
# Processing line: xnor g58(n4[13] ,n2462 ,n9[13]);
# Processing line: xnor g59(n4[12] ,n2468 ,n9[12]);
# Processing line: xnor g60(n3[19] ,n2471 ,n8[19]);
# Processing line: xnor g61(n4[11] ,n2464 ,n9[11]);
# Processing line: xnor g62(n4[10] ,n2460 ,n9[10]);
# Processing line: xnor g63(n3[18] ,n2469 ,n8[18]);
# Processing line: xnor g64(n4[9] ,n2470 ,n9[9]);
# Processing line: xnor g65(n4[8] ,n2467 ,n9[8]);
# Processing line: xnor g66(n3[17] ,n2473 ,n8[17]);
# Processing line: xnor g67(n4[7] ,n2465 ,n9[7]);
# Processing line: xnor g68(n4[6] ,n2463 ,n9[6]);
# Processing line: xnor g69(n3[60] ,n2468 ,n8[60]);
# Processing line: xnor g70(n3[56] ,n2467 ,n8[56]);
# Processing line: xnor g71(n4[5] ,n2461 ,n9[5]);
# Processing line: xnor g72(n4[4] ,n2459 ,n9[4]);
# Processing line: xnor g73(n3[49] ,n2473 ,n8[49]);
# Processing line: xnor g74(n4[3] ,n2471 ,n9[3]);
# Processing line: xnor g75(n4[2] ,n2469 ,n9[2]);
# Processing line: xnor g76(n3[14] ,n2472 ,n8[14]);
# Processing line: xnor g77(n4[1] ,n2473 ,n9[1]);
# Processing line: xnor g78(n3[13] ,n2462 ,n8[13]);
# Processing line: xnor g79(n5[62] ,n2472 ,n7[62]);
# Processing line: xnor g80(n3[12] ,n2468 ,n8[12]);
# Processing line: xnor g81(n3[11] ,n2464 ,n8[11]);
# Processing line: xnor g82(n5[61] ,n2462 ,n7[61]);
# Processing line: xnor g83(n5[60] ,n2468 ,n7[60]);
# Processing line: xnor g84(n5[59] ,n2464 ,n7[59]);
# Processing line: xnor g85(n5[58] ,n2460 ,n7[58]);
# Processing line: xnor g86(n3[10] ,n2460 ,n8[10]);
# Processing line: xnor g87(n5[57] ,n2470 ,n7[57]);
# Processing line: xnor g88(n5[56] ,n2467 ,n7[56]);
# Processing line: xnor g89(n3[9] ,n2470 ,n8[9]);
# Processing line: xnor g90(n5[55] ,n2465 ,n7[55]);
# Processing line: xnor g91(n5[54] ,n2463 ,n7[54]);
# Processing line: xnor g92(n3[62] ,n2472 ,n8[62]);
# Processing line: xnor g93(n3[7] ,n2465 ,n8[7]);
# Processing line: xnor g94(n5[53] ,n2461 ,n7[53]);
# Processing line: xnor g95(n5[52] ,n2459 ,n7[52]);
# Processing line: xnor g96(n5[51] ,n2471 ,n7[51]);
# Processing line: xnor g97(n5[50] ,n2469 ,n7[50]);
# Processing line: xnor g98(n3[59] ,n2464 ,n8[59]);
# Processing line: xnor g99(n3[6] ,n2463 ,n8[6]);
# Processing line: xnor g100(n5[49] ,n2473 ,n7[49]);
# Processing line: xnor g101(n3[8] ,n2467 ,n8[8]);
# Processing line: xnor g102(n3[5] ,n2461 ,n8[5]);
# Processing line: xnor g103(n5[46] ,n2472 ,n7[46]);
# Processing line: xnor g104(n3[55] ,n2465 ,n8[55]);
# Processing line: xnor g105(n3[4] ,n2459 ,n8[4]);
# Processing line: xnor g106(n3[48] ,n2466 ,n8[48]);
# Processing line: xnor g107(n4[30] ,n2472 ,n9[30]);
# Processing line: xnor g108(n3[3] ,n2471 ,n8[3]);
# Processing line: xnor g109(n5[43] ,n2464 ,n7[43]);
# Processing line: xnor g110(n5[42] ,n2460 ,n7[42]);
# Processing line: xnor g111(n3[2] ,n2469 ,n8[2]);
# Processing line: xnor g112(n5[41] ,n2470 ,n7[41]);
# Processing line: xnor g113(n5[40] ,n2467 ,n7[40]);
# Processing line: xnor g114(n3[1] ,n2473 ,n8[1]);
# Processing line: xnor g115(n5[39] ,n2465 ,n7[39]);
# Processing line: xnor g116(n5[38] ,n2463 ,n7[38]);
# Processing line: xnor g117(n5[37] ,n2461 ,n7[37]);
# Processing line: xnor g118(n5[36] ,n2459 ,n7[36]);
# Processing line: xnor g119(n5[35] ,n2471 ,n7[35]);
# Processing line: xnor g120(n5[34] ,n2469 ,n7[34]);
# Processing line: xnor g121(n3[61] ,n2462 ,n8[61]);
# Processing line: xnor g122(n3[45] ,n2462 ,n8[45]);
# Processing line: xnor g123(n5[33] ,n2473 ,n7[33]);
# Processing line: xnor g124(n3[46] ,n2472 ,n8[46]);
# Processing line: xnor g125(n4[62] ,n2472 ,n9[62]);
# Processing line: xnor g126(n5[30] ,n2472 ,n7[30]);
# Processing line: xnor g127(n3[43] ,n2464 ,n8[43]);
# Processing line: xnor g128(n4[61] ,n2462 ,n9[61]);
# Processing line: xnor g129(n5[29] ,n2462 ,n7[29]);
# Processing line: xnor g130(n5[28] ,n2468 ,n7[28]);
# Processing line: xnor g131(n4[60] ,n2468 ,n9[60]);
# Processing line: xnor g132(n5[27] ,n2464 ,n7[27]);
# Processing line: xnor g133(n5[26] ,n2460 ,n7[26]);
# Processing line: xnor g134(n4[59] ,n2464 ,n9[59]);
# Processing line: xnor g135(n5[25] ,n2470 ,n7[25]);
# Processing line: xnor g136(n5[24] ,n2467 ,n7[24]);
# Processing line: xnor g137(n4[58] ,n2460 ,n9[58]);
# Processing line: xnor g138(n5[23] ,n2465 ,n7[23]);
# Processing line: xnor g139(n5[22] ,n2463 ,n7[22]);
# Processing line: xnor g140(n4[57] ,n2470 ,n9[57]);
# Processing line: xnor g141(n5[21] ,n2461 ,n7[21]);
# Processing line: xnor g142(n5[20] ,n2459 ,n7[20]);
# Processing line: xnor g143(n4[56] ,n2467 ,n9[56]);
# Processing line: xnor g144(n5[19] ,n2471 ,n7[19]);
# Processing line: xnor g145(n5[18] ,n2469 ,n7[18]);
# Processing line: xnor g146(n3[44] ,n2468 ,n8[44]);
# Processing line: xnor g147(n3[41] ,n2470 ,n8[41]);
# Processing line: xnor g148(n5[17] ,n2473 ,n7[17]);
# Processing line: xnor g149(n4[55] ,n2465 ,n9[55]);
# Processing line: xnor g150(n3[42] ,n2460 ,n8[42]);
# Processing line: xnor g151(n4[54] ,n2463 ,n9[54]);
# Processing line: xnor g152(n5[14] ,n2472 ,n7[14]);
# Processing line: xnor g153(n3[40] ,n2467 ,n8[40]);
# Processing line: xnor g154(n4[53] ,n2461 ,n9[53]);
# Processing line: xnor g155(n5[13] ,n2462 ,n7[13]);
# Processing line: xnor g156(n5[12] ,n2468 ,n7[12]);
# Processing line: xnor g157(n4[52] ,n2459 ,n9[52]);
# Processing line: xnor g158(n5[11] ,n2464 ,n7[11]);
# Processing line: xnor g159(n5[10] ,n2460 ,n7[10]);
# Processing line: xnor g160(n3[39] ,n2465 ,n8[39]);
# Processing line: xnor g161(n4[51] ,n2471 ,n9[51]);
# Processing line: xnor g162(n5[9] ,n2470 ,n7[9]);
# Processing line: xnor g163(n5[8] ,n2467 ,n7[8]);
# Processing line: xnor g164(n4[50] ,n2469 ,n9[50]);
# Processing line: xnor g165(n5[7] ,n2465 ,n7[7]);
# Processing line: xnor g166(n5[6] ,n2463 ,n7[6]);
# Processing line: xnor g167(n3[54] ,n2463 ,n8[54]);
# Processing line: xnor g168(n3[38] ,n2463 ,n8[38]);
# Processing line: xnor g169(n5[5] ,n2461 ,n7[5]);
# Processing line: xnor g170(n5[4] ,n2459 ,n7[4]);
# Processing line: xnor g171(n4[49] ,n2473 ,n9[49]);
# Processing line: xnor g172(n5[3] ,n2471 ,n7[3]);
# Processing line: xnor g173(n5[2] ,n2469 ,n7[2]);
# Processing line: xnor g174(n3[53] ,n2461 ,n8[53]);
# Processing line: xnor g175(n3[37] ,n2461 ,n8[37]);
# Processing line: xnor g176(n5[1] ,n2473 ,n7[1]);
# Processing line: xnor g177(n4[46] ,n2472 ,n9[46]);
# Processing line: xnor g178(n3[36] ,n2459 ,n8[36]);
# Processing line: xnor g179(n3[35] ,n2471 ,n8[35]);
# Processing line: xnor g180(n4[45] ,n2462 ,n9[45]);
# Processing line: xnor g181(n4[44] ,n2468 ,n9[44]);
# Processing line: xnor g182(n4[43] ,n2464 ,n9[43]);
# Processing line: xnor g183(n4[42] ,n2460 ,n9[42]);
# Processing line: xnor g184(n3[34] ,n2469 ,n8[34]);
# Processing line: xnor g185(n4[41] ,n2470 ,n9[41]);
# Processing line: xnor g186(n4[40] ,n2467 ,n9[40]);
# Processing line: xnor g187(n3[33] ,n2473 ,n8[33]);
# Processing line: xnor g188(n4[39] ,n2465 ,n9[39]);
# Processing line: xnor g189(n4[38] ,n2463 ,n9[38]);
# Processing line: xnor g190(n3[52] ,n2459 ,n8[52]);
# Processing line: xnor g191(n4[37] ,n2461 ,n9[37]);
# Processing line: xnor g192(n4[36] ,n2459 ,n9[36]);
# Processing line: xnor g193(n4[35] ,n2471 ,n9[35]);
# Processing line: xnor g194(n4[34] ,n2469 ,n9[34]);
# Processing line: xnor g195(n3[30] ,n2472 ,n8[30]);
# Processing line: xnor g196(n4[33] ,n2473 ,n9[33]);
# Processing line: xnor g197(n3[58] ,n2460 ,n8[58]);
# Processing line: xnor g198(n3[29] ,n2462 ,n8[29]);
# Processing line: xnor g199(n5[44] ,n2468 ,n7[44]);
# Processing line: xnor g200(n4[0] ,n2457 ,n9[0]);
# Processing line: xnor g201(n5[63] ,n2458 ,n7[63]);
# Processing line: xnor g202(n3[0] ,n2457 ,n8[0]);
# Processing line: xnor g203(n4[63] ,n2458 ,n9[63]);
# Processing line: xnor g204(n3[63] ,n2458 ,n8[63]);
# Processing line: xnor g205(n5[0] ,n2457 ,n7[0]);
# Processing line: xnor g206(n2474 ,n10[47] ,n2448);
# Processing line: xnor g207(n2473 ,n10[49] ,n2445);
# Processing line: xnor g208(n2472 ,n10[62] ,n2441);
# Processing line: xnor g209(n2471 ,n10[51] ,n2456);
# Processing line: xnor g210(n2470 ,n10[57] ,n2442);
# Processing line: xnor g211(n2469 ,n10[50] ,n2443);
# Processing line: xnor g212(n2468 ,n10[60] ,n2444);
# Processing line: xnor g213(n2467 ,n10[56] ,n2446);
# Processing line: xnor g214(n2466 ,n10[48] ,n2447);
# Processing line: xnor g215(n2465 ,n10[55] ,n2449);
# Processing line: xnor g216(n2464 ,n10[59] ,n2450);
# Processing line: xnor g217(n2463 ,n10[54] ,n2451);
# Processing line: xnor g218(n2462 ,n10[61] ,n2452);
# Processing line: xnor g219(n2461 ,n10[53] ,n2453);
# Processing line: xnor g220(n2460 ,n10[58] ,n2454);
# Processing line: xnor g221(n2459 ,n10[52] ,n2455);
# Processing line: xnor g222(n2458 ,n10[47] ,n2433);
# Processing line: xnor g223(n2457 ,n10[48] ,n2432);
# Processing line: xnor g224(n2867 ,n2405 ,n2868);
# Processing line: xnor g225(n2721 ,n2414 ,n2[40]);
# Processing line: xnor g226(n2722 ,n2418 ,n2[41]);
# Processing line: xnor g227(n2723 ,n2421 ,n2[42]);
# Processing line: xnor g228(n2724 ,n2407 ,n2[43]);
# Processing line: xnor g229(n2725 ,n2415 ,n2[44]);
# Processing line: xnor g230(n2726 ,n2410 ,n2[45]);
# Processing line: xnor g231(n2564 ,n2[75] ,n2407);
# Processing line: xnor g232(n2729 ,n2420 ,n2[48]);
# Processing line: xnor g233(n2731 ,n2409 ,n2[50]);
# Processing line: xnor g234(n2732 ,n2416 ,n2[51]);
# Processing line: xnor g235(n2733 ,n2408 ,n2[52]);
# Processing line: xnor g236(n2734 ,n2417 ,n2[53]);
# Processing line: xnor g237(n2735 ,n2411 ,n2[54]);
# Processing line: xnor g238(n2736 ,n2419 ,n2[55]);
# Processing line: xnor g239(n2737 ,n2414 ,n2[56]);
# Processing line: xnor g240(n2837 ,n2413 ,n2838);
# Processing line: xnor g241(n2712 ,n2413 ,n2[31]);
# Processing line: xnor g242(n2744 ,n2[63] ,n2413);
# Processing line: xnor g243(n2728 ,n2413 ,n2[47]);
# Processing line: xnor g244(n2568 ,n2[79] ,n2413);
# Processing line: xnor g245(n2696 ,n2413 ,n2[15]);
# Processing line: xnor g246(n2616 ,n2[127] ,n2413);
# Processing line: xnor g247(n2600 ,n2[111] ,n2413);
# Processing line: xnor g248(n2584 ,n2[95] ,n2413);
# Processing line: xnor g249(n2933 ,n2413 ,n2934);
# Processing line: xnor g250(n2901 ,n2413 ,n2902);
# Processing line: xnor g251(n2869 ,n2413 ,n2870);
# Processing line: xnor g252(n2841 ,n2406 ,n2842);
# Processing line: xnor g253(n2835 ,n2405 ,n2836);
# Processing line: xnor g254(n2809 ,n2810 ,n2406);
# Processing line: xnor g255(n2743 ,n2[62] ,n2405);
# Processing line: xnor g256(n2730 ,n2406 ,n2[49]);
# Processing line: xnor g257(n2727 ,n2405 ,n2[46]);
# Processing line: xnor g258(n2714 ,n2406 ,n2[33]);
# Processing line: xnor g259(n2711 ,n2405 ,n2[30]);
# Processing line: xnor g260(n2615 ,n2[126] ,n2405);
# Processing line: xnor g261(n2698 ,n2406 ,n2[17]);
# Processing line: xnor g262(n2695 ,n2405 ,n2[14]);
# Processing line: xnor g263(n2682 ,n2406 ,n2[1]);
# Processing line: xnor g264(n2602 ,n2[113] ,n2406);
# Processing line: xnor g265(n2599 ,n2[110] ,n2405);
# Processing line: xnor g266(n2586 ,n2[97] ,n2406);
# Processing line: xnor g267(n2583 ,n2[94] ,n2405);
# Processing line: xnor g268(n2570 ,n2[81] ,n2406);
# Processing line: xnor g269(n2567 ,n2[78] ,n2405);
# Processing line: xnor g270(n2554 ,n2[65] ,n2406);
# Processing line: xnor g271(n2931 ,n2405 ,n2932);
# Processing line: xnor g272(n2905 ,n2406 ,n2906);
# Processing line: xnor g273(n2899 ,n2405 ,n2900);
# Processing line: xnor g274(n2873 ,n2406 ,n2874);
# Processing line: xnor g275(n2738 ,n2418 ,n2[57]);
# Processing line: xnor g276(n2865 ,n2410 ,n2866);
# Processing line: xnor g277(n2863 ,n2415 ,n2864);
# Processing line: xnor g278(n2603 ,n2[114] ,n2409);
# Processing line: xnor g279(n2861 ,n2407 ,n2862);
# Processing line: xnor g280(n2859 ,n2421 ,n2860);
# Processing line: xnor g281(n2857 ,n2418 ,n2858);
# Processing line: xnor g282(n2855 ,n2414 ,n2856);
# Processing line: xnor g283(n2853 ,n2419 ,n2854);
# Processing line: xnor g284(n2851 ,n2411 ,n2852);
# Processing line: xnor g285(n2849 ,n2417 ,n2850);
# Processing line: xnor g286(n2605 ,n2[116] ,n2408);
# Processing line: xnor g287(n2847 ,n2408 ,n2848);
# Processing line: xnor g288(n2845 ,n2416 ,n2846);
# Processing line: xnor g289(n2843 ,n2409 ,n2844);
# Processing line: xnor g290(n2839 ,n2420 ,n2840);
# Processing line: xnor g291(n2833 ,n2410 ,n2834);
# Processing line: xnor g292(n2831 ,n2415 ,n2832);
# Processing line: xnor g293(n2829 ,n2407 ,n2830);
# Processing line: xnor g294(n2827 ,n2421 ,n2828);
# Processing line: xnor g295(n2825 ,n2418 ,n2826);
# Processing line: xnor g296(n2823 ,n2414 ,n2824);
# Processing line: xnor g297(n2821 ,n2419 ,n2822);
# Processing line: xnor g298(n2819 ,n2411 ,n2820);
# Processing line: xnor g299(n2607 ,n2[118] ,n2411);
# Processing line: xnor g300(n2817 ,n2417 ,n2818);
# Processing line: xnor g301(n2561 ,n2[72] ,n2414);
# Processing line: xnor g302(n2815 ,n2408 ,n2816);
# Processing line: xnor g303(n2713 ,n2420 ,n2[32]);
# Processing line: xnor g304(n2813 ,n2416 ,n2814);
# Processing line: xnor g305(n2560 ,n2[71] ,n2419);
# Processing line: xnor g306(n2811 ,n2409 ,n2812);
# Processing line: xnor g307(n2742 ,n2[61] ,n2410);
# Processing line: xnor g308(n2741 ,n2[60] ,n2415);
# Processing line: xnor g309(n2740 ,n2407 ,n2[59]);
# Processing line: xnor g310(n2739 ,n2421 ,n2[58]);
# Processing line: nor g311(n2456 ,n2479 ,n2426);
# Processing line: nor g312(n2455 ,n2481 ,n2437);
# Processing line: nor g313(n2454 ,n2483 ,n2439);
# Processing line: nor g314(n2453 ,n2482 ,n2424);
# Processing line: nor g315(n2452 ,n2488 ,n2431);
# Processing line: nor g316(n2451 ,n2484 ,n2428);
# Processing line: nor g317(n2450 ,n2487 ,n2429);
# Processing line: nor g318(n2449 ,n2486 ,n2438);
# Processing line: nor g319(n2448 ,n2422 ,n2436);
# Processing line: nor g320(n2447 ,n2412 ,n2434);
# Processing line: nor g321(n2446 ,n2476 ,n2423);
# Processing line: nor g322(n2445 ,n2477 ,n2425);
# Processing line: nor g323(n2444 ,n2485 ,n2427);
# Processing line: nor g324(n2443 ,n2475 ,n2435);
# Processing line: nor g325(n2442 ,n2480 ,n2440);
# Processing line: nor g326(n2441 ,n2478 ,n2430);
# Processing line: xnor g327(n2720 ,n2419 ,n2[39]);
# Processing line: xnor g328(n2719 ,n2411 ,n2[38]);
# Processing line: xnor g329(n2718 ,n2417 ,n2[37]);
# Processing line: xnor g330(n2717 ,n2408 ,n2[36]);
# Processing line: xnor g331(n2716 ,n2416 ,n2[35]);
# Processing line: xnor g332(n2715 ,n2409 ,n2[34]);
# Processing line: xnor g333(n2710 ,n2410 ,n2[29]);
# Processing line: xnor g334(n2709 ,n2415 ,n2[28]);
# Processing line: xnor g335(n2708 ,n2407 ,n2[27]);
# Processing line: xnor g336(n2707 ,n2421 ,n2[26]);
# Processing line: xnor g337(n2706 ,n2418 ,n2[25]);
# Processing line: xnor g338(n2705 ,n2414 ,n2[24]);
# Processing line: xnor g339(n2704 ,n2419 ,n2[23]);
# Processing line: xnor g340(n2703 ,n2411 ,n2[22]);
# Processing line: xnor g341(n2702 ,n2417 ,n2[21]);
# Processing line: xnor g342(n2701 ,n2408 ,n2[20]);
# Processing line: xnor g343(n2569 ,n2[80] ,n2420);
# Processing line: xnor g344(n2700 ,n2416 ,n2[19]);
# Processing line: xnor g345(n2697 ,n2420 ,n2[16]);
# Processing line: xnor g346(n2694 ,n2410 ,n2[13]);
# Processing line: xnor g347(n2693 ,n2415 ,n2[12]);
# Processing line: xnor g348(n2692 ,n2407 ,n2[11]);
# Processing line: xnor g349(n2691 ,n2421 ,n2[10]);
# Processing line: xnor g350(n2690 ,n2418 ,n2[9]);
# Processing line: xnor g351(n2689 ,n2414 ,n2[8]);
# Processing line: xnor g352(n2681 ,n2[0] ,n2420);
# Processing line: xnor g353(n2688 ,n2419 ,n2[7]);
# Processing line: xnor g354(n2687 ,n2411 ,n2[6]);
# Processing line: xnor g355(n2571 ,n2[82] ,n2409);
# Processing line: xnor g356(n2686 ,n2417 ,n2[5]);
# Processing line: xnor g357(n2685 ,n2408 ,n2[4]);
# Processing line: xnor g358(n2573 ,n2[84] ,n2408);
# Processing line: xnor g359(n2684 ,n2416 ,n2[3]);
# Processing line: xnor g360(n2683 ,n2409 ,n2[2]);
# Processing line: xnor g361(n2572 ,n2[83] ,n2416);
# Processing line: xnor g362(n2614 ,n2[125] ,n2410);
# Processing line: xnor g363(n2613 ,n2[124] ,n2415);
# Processing line: xnor g364(n2612 ,n2[123] ,n2407);
# Processing line: xnor g365(n2611 ,n2[122] ,n2421);
# Processing line: xnor g366(n2610 ,n2[121] ,n2418);
# Processing line: xnor g367(n2609 ,n2[120] ,n2414);
# Processing line: xnor g368(n2608 ,n2[119] ,n2419);
# Processing line: xnor g369(n2606 ,n2[117] ,n2417);
# Processing line: xnor g370(n2604 ,n2[115] ,n2416);
# Processing line: xnor g371(n2601 ,n2[112] ,n2420);
# Processing line: xnor g372(n2576 ,n2[87] ,n2419);
# Processing line: xnor g373(n2598 ,n2[109] ,n2410);
# Processing line: xnor g374(n2594 ,n2[105] ,n2418);
# Processing line: xnor g375(n2591 ,n2[102] ,n2411);
# Processing line: xnor g376(n2590 ,n2[101] ,n2417);
# Processing line: xnor g377(n2589 ,n2[100] ,n2408);
# Processing line: xnor g378(n2585 ,n2[96] ,n2420);
# Processing line: xnor g379(n2582 ,n2[93] ,n2410);
# Processing line: xnor g380(n2581 ,n2[92] ,n2415);
# Processing line: xnor g381(n2555 ,n2[66] ,n2409);
# Processing line: xnor g382(n2579 ,n2[90] ,n2421);
# Processing line: xnor g383(n2578 ,n2[89] ,n2418);
# Processing line: xnor g384(n2577 ,n2[88] ,n2414);
# Processing line: xnor g385(n2556 ,n2[67] ,n2416);
# Processing line: xnor g386(n2575 ,n2[86] ,n2411);
# Processing line: xnor g387(n2580 ,n2[91] ,n2407);
# Processing line: xnor g388(n2574 ,n2[85] ,n2417);
# Processing line: xnor g389(n2566 ,n2[77] ,n2410);
# Processing line: xnor g390(n2565 ,n2[76] ,n2415);
# Processing line: xnor g391(n2563 ,n2[74] ,n2421);
# Processing line: xnor g392(n2562 ,n2[73] ,n2418);
# Processing line: xnor g393(n2559 ,n2[70] ,n2411);
# Processing line: xnor g394(n2558 ,n2[69] ,n2417);
# Processing line: xnor g395(n2557 ,n2[68] ,n2408);
# Processing line: xnor g396(n2553 ,n2[64] ,n2420);
# Processing line: xnor g397(n2587 ,n2[98] ,n2409);
# Processing line: xnor g398(n2588 ,n2[99] ,n2416);
# Processing line: xnor g399(n2699 ,n2409 ,n2[18]);
# Processing line: xnor g400(n2592 ,n2[103] ,n2419);
# Processing line: xnor g401(n2929 ,n2410 ,n2930);
# ...
# Processing line: nor g3074(n1209 ,n1040 ,n1208);
# Processing line: not g3183(n1135 ,n1134);
# Processing line: nor g3184(n1134 ,n1058 ,n1133);
# Processing line: xor g3185(n2751 ,n1122 ,n1132);
# Processing line: nor g3186(n1133 ,n1122 ,n1132);
# Processing line: nor g3187(n1132 ,n1059 ,n1131);
# Processing line: xor g3188(n2750 ,n1121 ,n1130);
# Processing line: nor g3189(n1131 ,n1121 ,n1130);
# Processing line: nor g3190(n1130 ,n1057 ,n1129);
# Processing line: xnor g3191(n2749 ,n1120 ,n1127);
# Processing line: nor g3192(n1129 ,n1120 ,n1128);
# Processing line: not g3193(n1128 ,n1127);
# Processing line: nor g3194(n1127 ,n1028 ,n1126);
# Processing line: xnor g3195(n2748 ,n1085 ,n1125);
# Processing line: nor g3196(n1126 ,n1085 ,n1125);
# Processing line: nor g3197(n1125 ,n1020 ,n1124);
# Processing line: xnor g3198(n2747 ,n1069 ,n1061);
# Processing line: nor g3199(n1124 ,n1061 ,n1069);
# Processing line: nor g3200(n2746 ,n1061 ,n1060);
# Processing line: xnor g3201(n1123 ,n2829 ,n11[42]);
# Processing line: xnor g3202(n1122 ,n2819 ,n11[37]);
# Processing line: xnor g3203(n1121 ,n2817 ,n11[36]);
# Processing line: xnor g3204(n1120 ,n2815 ,n11[35]);
# Processing line: xnor g3205(n1119 ,n2853 ,n11[38]);
# Processing line: xnor g3206(n1118 ,n2851 ,n11[37]);
# Processing line: xnor g3207(n1117 ,n2895 ,n11[43]);
# Processing line: xnor g3208(n1116 ,n2925 ,n11[42]);
# Processing line: xnor g3209(n1115 ,n2849 ,n11[36]);
# Processing line: xnor g3210(n1114 ,n2915 ,n11[37]);
# Processing line: xnor g3211(n1113 ,n2847 ,n11[35]);
# Processing line: xnor g3212(n1112 ,n2893 ,n11[42]);
# Processing line: xnor g3213(n1111 ,n2845 ,n11[34]);
# Processing line: xnor g3214(n1110 ,n2843 ,n11[33]);
# Processing line: xnor g3215(n1109 ,n2891 ,n11[41]);
# Processing line: xnor g3216(n1108 ,n2911 ,n11[35]);
# Processing line: xnor g3217(n1107 ,n2919 ,n11[39]);
# Processing line: xnor g3218(n1106 ,n2889 ,n11[40]);
# Processing line: xnor g3219(n1105 ,n2837 ,n11[46]);
# Processing line: xnor g3220(n1104 ,n2835 ,n11[45]);
# Processing line: xnor g3221(n1103 ,n2913 ,n11[36]);
# Processing line: xnor g3222(n1102 ,n2887 ,n11[39]);
# Processing line: xnor g3223(n1101 ,n2833 ,n11[44]);
# Processing line: xnor g3224(n1100 ,n2831 ,n11[43]);
# Processing line: xnor g3225(n1099 ,n2923 ,n11[41]);
# Processing line: xnor g3226(n1098 ,n2885 ,n11[38]);
# Processing line: xnor g3227(n1097 ,n2827 ,n11[41]);
# Processing line: xnor g3228(n1096 ,n2883 ,n11[37]);
# Processing line: xnor g3229(n1095 ,n2823 ,n11[39]);
# Processing line: xnor g3230(n1094 ,n2825 ,n11[40]);
# Processing line: xnor g3231(n1093 ,n2921 ,n11[40]);
# Processing line: xnor g3232(n1092 ,n2821 ,n11[38]);
# Processing line: xnor g3233(n1091 ,n2857 ,n11[40]);
# Processing line: xnor g3234(n1090 ,n2909 ,n11[34]);
# Processing line: xnor g3235(n1089 ,n2879 ,n11[35]);
# Processing line: xnor g3236(n1088 ,n2929 ,n11[44]);
# Processing line: xnor g3237(n1087 ,n2899 ,n11[45]);
# Processing line: xnor g3238(n1086 ,n2877 ,n11[34]);
# Processing line: xnor g3239(n1085 ,n2813 ,n11[34]);
# Processing line: xnor g3240(n1084 ,n2907 ,n11[33]);
# Processing line: xnor g3241(n1083 ,n2875 ,n11[33]);
# Processing line: xnor g3242(n1082 ,n2917 ,n11[38]);
# Processing line: xnor g3243(n1081 ,n2861 ,n11[42]);
# Processing line: xnor g3244(n1080 ,n2855 ,n11[39]);
# Processing line: xnor g3245(n1079 ,n2897 ,n11[44]);
# Processing line: xnor g3246(n1078 ,n2901 ,n11[46]);
# Processing line: xnor g3247(n1077 ,n2881 ,n11[36]);
# Processing line: xnor g3248(n1076 ,n2859 ,n11[41]);
# Processing line: xnor g3249(n1075 ,n2863 ,n11[43]);
# Processing line: xnor g3250(n1074 ,n2869 ,n11[46]);
# Processing line: xnor g3251(n1073 ,n2865 ,n11[44]);
# Processing line: xnor g3252(n1072 ,n2931 ,n11[45]);
# Processing line: xnor g3253(n1071 ,n2867 ,n11[45]);
# Processing line: xnor g3254(n1070 ,n2927 ,n11[43]);
# Processing line: xnor g3255(n1069 ,n2811 ,n11[33]);
# Processing line: xnor g3256(n1068 ,n2841 ,n11[32]);
# Processing line: xnor g3257(n1067 ,n2839 ,n11[31]);
# Processing line: xnor g3258(n1066 ,n2873 ,n11[32]);
# Processing line: xnor g3259(n1065 ,n2871 ,n11[31]);
# Processing line: xnor g3260(n1064 ,n2905 ,n11[32]);
# Processing line: xnor g3261(n1063 ,n2903 ,n11[31]);
# Processing line: xnor g3262(n1062 ,n11[46] ,n2933);
# Processing line: nor g3263(n1060 ,n2809 ,n10[49]);
# Processing line: nor g3264(n1059 ,n998 ,n989);
# Processing line: nor g3265(n1058 ,n993 ,n987);
# Processing line: nor g3266(n1057 ,n996 ,n988);
# Processing line: nor g3267(n1056 ,n992 ,n995);
# Processing line: nor g3268(n1055 ,n2859 ,n11[41]);
# Processing line: nor g3269(n1054 ,n2897 ,n11[44]);
# Processing line: nor g3270(n1053 ,n2853 ,n11[38]);
# Processing line: nor g3271(n1052 ,n2871 ,n11[31]);
# Processing line: nor g3272(n1051 ,n2915 ,n11[37]);
# Processing line: nor g3273(n1050 ,n2851 ,n11[37]);
# Processing line: nor g3274(n1049 ,n2895 ,n11[43]);
# Processing line: nor g3275(n1048 ,n2929 ,n11[44]);
# Processing line: nor g3276(n1047 ,n2893 ,n11[42]);
# Processing line: nor g3277(n1046 ,n2917 ,n11[38]);
# Processing line: nor g3278(n1045 ,n2891 ,n11[41]);
# Processing line: nor g3279(n1044 ,n2843 ,n11[33]);
# Processing line: nor g3280(n1043 ,n2909 ,n11[34]);
# Processing line: nor g3281(n1042 ,n2903 ,n11[31]);
# Processing line: nor g3282(n1041 ,n2869 ,n11[46]);
# Processing line: nor g3283(n1040 ,n2889 ,n11[40]);
# Processing line: nor g3284(n1039 ,n2849 ,n11[36]);
# Processing line: nor g3285(n1038 ,n2841 ,n11[32]);
# Processing line: nor g3286(n1037 ,n2885 ,n11[38]);
# Processing line: nor g3287(n1036 ,n2835 ,n11[45]);
# Processing line: nor g3288(n1035 ,n2831 ,n11[43]);
# Processing line: nor g3289(n1034 ,n2911 ,n11[35]);
# Processing line: nor g3290(n1033 ,n2855 ,n11[39]);
# Processing line: nor g3291(n1032 ,n2827 ,n11[41]);
# Processing line: nor g3292(n1031 ,n991 ,n994);
# Processing line: nor g3293(n1061 ,n997 ,n990);
# Processing line: nor g3294(n1030 ,n2875 ,n11[33]);
# Processing line: nor g3295(n1029 ,n2877 ,n11[34]);
# Processing line: nor g3296(n1028 ,n2813 ,n11[34]);
# Processing line: nor g3297(n1027 ,n2923 ,n11[41]);
# Processing line: nor g3298(n1026 ,n2823 ,n11[39]);
# Processing line: nor g3299(n1025 ,n2921 ,n11[40]);
# Processing line: nor g3300(n1024 ,n2879 ,n11[35]);
# Processing line: nor g3301(n1023 ,n2857 ,n11[40]);
# Processing line: nor g3302(n1022 ,n2907 ,n11[33]);
# Processing line: nor g3303(n1021 ,n2927 ,n11[43]);
# Processing line: nor g3304(n1020 ,n2811 ,n11[33]);
# Processing line: nor g3305(n1019 ,n2839 ,n11[31]);
# Processing line: nor g3306(n1018 ,n2881 ,n11[36]);
# Processing line: nor g3307(n1017 ,n2873 ,n11[32]);
# Processing line: nor g3308(n1016 ,n2887 ,n11[39]);
# Processing line: nor g3309(n1015 ,n2899 ,n11[45]);
# Processing line: nor g3310(n1014 ,n2847 ,n11[35]);
# Processing line: nor g3311(n1013 ,n2867 ,n11[45]);
# Processing line: nor g3312(n1012 ,n2901 ,n11[46]);
# Processing line: nor g3313(n1011 ,n2913 ,n11[36]);
# Processing line: nor g3314(n1010 ,n2845 ,n11[34]);
# Processing line: nor g3315(n1009 ,n2905 ,n11[32]);
# Processing line: nor g3316(n1008 ,n2919 ,n11[39]);
# Processing line: nor g3317(n1007 ,n2821 ,n11[38]);
# Processing line: nor g3318(n1006 ,n2863 ,n11[43]);
# Processing line: nor g3319(n1005 ,n2865 ,n11[44]);
# Processing line: nor g3320(n1004 ,n2925 ,n11[42]);
# Processing line: nor g3321(n1003 ,n2833 ,n11[44]);
# Processing line: nor g3322(n1002 ,n2861 ,n11[42]);
# Processing line: nor g3323(n1001 ,n2883 ,n11[37]);
# Processing line: nor g3324(n1000 ,n2931 ,n11[45]);
# Processing line: nor g3325(n999 ,n2837 ,n11[46]);
# Processing line: not g3326(n998 ,n2817);
# Processing line: not g3327(n997 ,n2809);
# Processing line: not g3328(n996 ,n2815);
# Processing line: not g3329(n995 ,n11[42]);
# Processing line: not g3330(n994 ,n11[40]);
# Processing line: not g3331(n993 ,n2819);
# Processing line: not g3332(n992 ,n2829);
# Processing line: not g3333(n991 ,n2825);
# Processing line: not g3334(n990 ,n10[49]);
# Processing line: not g3335(n989 ,n11[36]);
# Processing line: not g3336(n988 ,n11[35]);
# Processing line: not g3337(n987 ,n11[37]);
# Processing line: xor g3338(n2935 ,n12[2] ,n1255);
# Processing line: nor g3339(n2936 ,n1255 ,n1254);
# Processing line: nor g3340(n1255 ,n1253 ,n1252);
# Processing line: nor g3341(n1254 ,n12[1] ,n12[0]);
# Processing line: not g3342(n1253 ,n12[1]);
# Processing line: not g3343(n1252 ,n12[0]);
# Processing line: not g3344(n2940 ,n1);
# Processing line: dff g3345(.RN(1'b1), .SN(n2940), .CK(n0), .D(n2939), .Q(n14[0]));
# Processing line: xor g3346(n2939 ,n2938 ,n2937);
# Processing line: xnor g3347(n2938 ,n10[60] ,n14[15]);
# Processing line: xnor g3348(n2937 ,n14[10] ,n14[12]);
# Processing line: dff g3349(.RN(n2940), .SN(1'b1), .CK(n0), .D(n14[9]), .Q(n10[57]));
# Processing line: dff g3350(.RN(1'b1), .SN(n2940), .CK(n0), .D(n10[51]), .Q(n14[5]));
# Processing line: dff g3351(.RN(n2940), .SN(1'b1), .CK(n0), .D(n10[48]), .Q(n10[49]));
# Processing line: dff g3352(.RN(n2940), .SN(1'b1), .CK(n0), .D(n10[55]), .Q(n10[56]));
# Processing line: dff g3353(.RN(n2940), .SN(1'b1), .CK(n0), .D(n14[11]), .Q(n10[59]));
# Processing line: dff g3354(.RN(n2940), .SN(1'b1), .CK(n0), .D(n14[10]), .Q(n10[58]));
# Processing line: dff g3355(.RN(n2940), .SN(1'b1), .CK(n0), .D(n10[60]), .Q(n10[61]));
# Processing line: dff g3356(.RN(1'b1), .SN(n2940), .CK(n0), .D(n10[55]), .Q(n14[9]));
# Processing line: dff g3357(.RN(1'b1), .SN(n2940), .CK(n0), .D(n10[60]), .Q(n14[14]));
# Processing line: dff g3358(.RN(n2940), .SN(1'b1), .CK(n0), .D(n14[7]), .Q(n10[55]));
# Processing line: dff g3359(.RN(1'b1), .SN(n2940), .CK(n0), .D(n14[11]), .Q(n14[12]));
# Processing line: dff g3360(.RN(1'b1), .SN(n2940), .CK(n0), .D(n14[14]), .Q(n14[15]));
# Processing line: dff g3361(.RN(n2940), .SN(1'b1), .CK(n0), .D(n14[0]), .Q(n10[48]));
# Processing line: dff g3362(.RN(1'b1), .SN(n2940), .CK(n0), .D(n10[53]), .Q(n14[7]));
# Processing line: dff g3363(.RN(n2940), .SN(1'b1), .CK(n0), .D(n14[15]), .Q(n10[47]));
# Processing line: dff g3364(.RN(n2940), .SN(1'b1), .CK(n0), .D(n14[2]), .Q(n10[50]));
# Processing line: dff g3365(.RN(n2940), .SN(1'b1), .CK(n0), .D(n10[51]), .Q(n10[52]));
# Processing line: dff g3366(.RN(n2940), .SN(1'b1), .CK(n0), .D(n14[14]), .Q(n10[62]));
# Processing line: dff g3367(.RN(n2940), .SN(1'b1), .CK(n0), .D(n10[53]), .Q(n10[54]));
# Processing line: dff g3368(.RN(1'b1), .SN(n2940), .CK(n0), .D(n14[2]), .Q(n14[3]));
# Processing line: dff g3369(.RN(1'b1), .SN(n2940), .CK(n0), .D(n10[48]), .Q(n14[2]));
# Processing line: dff g3370(.RN(1'b1), .SN(n2940), .CK(n0), .D(n14[10]), .Q(n14[11]));
# Processing line: dff g3371(.RN(n2940), .SN(1'b1), .CK(n0), .D(n14[5]), .Q(n10[53]));
# Processing line: dff g3372(.RN(n2940), .SN(1'b1), .CK(n0), .D(n14[3]), .Q(n10[51]));
# Processing line: dff g3373(.RN(1'b1), .SN(n2940), .CK(n0), .D(n14[9]), .Q(n14[10]));
# Processing line: dff g3374(.RN(n2940), .SN(1'b1), .CK(n0), .D(n14[12]), .Q(n10[60]));
# Processing line: endmodule
# ✅ Graph feature files saved.
